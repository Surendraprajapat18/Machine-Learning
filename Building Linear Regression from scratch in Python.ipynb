# %% [markdown]
# Linear Regression:
#
# Y = wX + b
#
# Y --> Dependent Variable
#
# X --> Independent Variable
#
# w --> weight
#
# b --> bias

# %% [markdown]
# **Gradient Descent:**
#
# Gradient Descent is an optimization algorithm used for minimizing the loss function in various machine learning algorithms. It is used for updating the parameters of the learning model.
#
# w  =  w - α*dw
#
# b  =  b - α*db

# %% [markdown]
# **Learning Rate:**
#
# Learning rate is a tuning parameter in an optimization algorithm that determines the step size at each iteration while moving toward a minimum of a loss function.

# %% [markdown]
# ![dw .png](data:image/png;base64,...)

# %% [markdown]
# ![db.png](data:image/png;base64,...)

# %%
import pandas as pd 
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

import linear_reg_module as lrg # linear_reg_Model.py

# %% [markdown]
# Linear Regression

# %% [markdown]
# Using Linear Regression Model for prediction

# %% [markdown]
# 1. Set Learning Rate & Number of Iteratons; Initiate Random weight and bias value
#
# 2. Build Linear Regression Equatio y = wx+b
#
# 3. Find the "y pred" value for given x value for the corresponding weight & bias
#
# 4. Check the loss function for these parameter values.
#
# 5. Updates the patameter values using Gradient Descent.

# %%
salary_data = pd.read_csv("/content/salary_data.csv")

# %%
salary_data.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
salary_data.tail()
# Out:
#     YearsExperience  Salary
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
salary_data.shape
# Out:
# (30, 2)

# %%
salary_data.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
salary_data.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
x = salary_data.iloc[:,:-1].values
y = salary_data.iloc[:,1].values

# %%
print(x, y)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]] [ 39343  46205  37731  43525  39891  56642  60150  54445  64445  57189
#   63218  55794  56957  57081  61111  67938  66029  83088  81363  93940
#   91738  98273 101302 113812 109431 105582 116969 112635 122391 121872]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=2)

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (30, 1) (20, 1) (10, 1)

# %%
model = lrg.Linear_Regression(learning_rate = 0.02, no_of_iterations= 1000)

# %%
model.fit(x_train, y_train)

# %%
# printing the parameter values (weeight and bias)
print('weight = ', model.w[0])
print('bias = ', model.b)
# Out:
# weight =  9514.400999035135
# bias =  23697.406507136307

# %% [markdown]
# y = 9514(x) + 23697
#
# salary = 9514(experiance) + 23697

# %% [markdown]
# predict the salary value for test data

# %%
test_data_prediction = model.predict(x_test)

# %%
test_data_prediction
# Out:
# array([ 36066.12780588,  34163.24760607,  66512.21100279,  58900.69020357,
#         91249.65360029,  80783.81250135, 101715.49469922,  52240.60950424,
#         42726.20850521,  88395.33330058])

# %% [markdown]
# Visualizing the predicted values & Values

# %%
plt.scatter(x_test, y_test, color='red')
plt.plot(x_test, test_data_prediction, color='blue')
plt.xlabel('Work Experience')
plt.ylabel('Salary')
plt.title('Salary vs Experience')
plt.show()
