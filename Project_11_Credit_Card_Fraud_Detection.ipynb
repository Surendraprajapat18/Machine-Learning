# %% [markdown]
# # Project 11. Credit Card Fraud Detection using Machine Learning in Python
#
# Surendra Prajapat

# %%
# Import required librery
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# DataSet Link : https://bit.ly/3J7G3of
credit_card_data = pd.read_csv("/content/creditcard.csv")

# %%
# first five row
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# last five row
credit_card_data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
credit_card_data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
# null value present or not in dataset
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit_card_data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# compare the values for both transcation
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Under Sampling
#
# Build a sample dataset containing similar distribution of normal transaction and Fraudulent Transaction
#
# Number of Fraudulent Transactions == 492

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# Concat two dataset

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 208100  136972.0  1.658927  0.689136 -1.163555  4.300544  0.381701 -0.353974
# 208209  137015.0 -0.025029 -0.345617 -0.610432 -2.503417 -1.027652  1.085349
# 78747    57682.0  1.114837 -0.278271  1.710821  1.241614 -1.441260 -0.151394
# 117062   74525.0  0.965423 -0.792412  0.719592  0.493993 -1.293798 -0.456804
# 267919  162984.0  1.876835 -0.502853 -0.296673  1.046891 -0.348574  0.708139
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 208100 -0.009362  0.037410 -0.592964  ... -0.367837 -1.285141  0.303342
# 208209  1.662186 -0.740468  0.359285  ... -0.212020 -0.006139  0.222861
# 78747  -0.776900  0.084722  1.287963  ...  0.068812  0.716531 -0.088147
# 117062 -0.422659  0.002849 -1.074268  ... -0.401126 -1.107516  0.077568
# 267919 -0.880436  0.332611  1.115571  ...  0.052152  0.170920  0.113751
#
# ...

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_dataset.shape
# Out:
# (984, 31)

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      93752.250000  0.009129 -0.050860  0.010106  0.052375 -0.009529
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.031008 -0.029023 -0.013218 -0.035169  ... -0.029863  0.020590
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.012732 -0.037878  0.020075  0.013040 -0.021498 -0.013198 -0.018538
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.057683
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Spliting data into features & Targets

# %%
x = new_dataset.drop(columns = 'Class', axis = 1)
y = new_dataset['Class']

# %%
print(x)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 208100  136972.0  1.658927  0.689136 -1.163555  4.300544  0.381701 -0.353974
# 208209  137015.0 -0.025029 -0.345617 -0.610432 -2.503417 -1.027652  1.085349
# 78747    57682.0  1.114837 -0.278271  1.710821  1.241614 -1.441260 -0.151394
# 117062   74525.0  0.965423 -0.792412  0.719592  0.493993 -1.293798 -0.456804
# 267919  162984.0  1.876835 -0.502853 -0.296673  1.046891 -0.348574  0.708139
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(y)
# Out:
# 208100    0
# 208209    0
# 78747     0
# 117062    0
# 267919    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=2)

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %%
print(x_train)
# Out:
#             Time         V1        V2         V3        V4         V5  \
# 100623   67571.0  -0.758469 -0.045410  -0.168438 -1.313275  -1.901763
# 217459  140898.0  -0.579914  1.142524  -0.722849 -0.375098   0.625102
# 58719    48516.0   1.181587  0.251616   0.760874  1.197358  -0.709371
# 24614    33303.0   1.425202 -1.167404   0.192354 -1.549624  -1.212251
# 197578  132081.0   2.029377 -0.663996  -0.931991 -0.965968  -0.261354
# ...          ...        ...       ...        ...       ...        ...
# 211119  138269.0  -0.358703  1.912924  -0.699201  4.352827  -0.187973
# 99995    67374.0  -1.336121  1.671947   0.994155  0.420318  -0.440923
# 223618  143456.0  -2.006582  3.676577  -5.463811  7.232058  -1.627859
# 43061    41353.0 -15.020981  8.075240 -16.298091  5.664820 -11.918153
# 160621  113500.0   2.055797 -0.326668  -2.752041 -0.842316   2.463072
#
#               V6         V7        V8        V9  ...       V20       V21  \
# ...

# %%
print(y_train)
# Out:
# 100623    1
# 217459    0
# 58719     0
# 24614     0
# 197578    0
#          ..
# 211119    0
# 99995     0
# 223618    1
# 43061     1
# 160621    0
# Name: Class, Length: 787, dtype: int64

# %% [markdown]
# Model Evalution

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
x_train_prediction = model.predict(x_train)
training_data_accuracy = accuracy_score(x_train_prediction, y_train)

# %%
print("Accuracy of traning data Accuracy: ", training_data_accuracy)
# Out:
# Accuracy of traning data Accuracy:  0.9390088945362135

# %%
x_test_prediction = model.predict(x_test)
test_data_accuracy = accuracy_score(y_test, x_test_prediction)

# %%
print("Accuracy of test data Accuracy: ", test_data_accuracy)
# Out:
# Accuracy of test data Accuracy:  0.9187817258883249

# %% [markdown]
# Building a Predicting System

# %%
input_data = (165132,-7.50392623748137,-0.360628009949399,-3.83095228272519,2.48610285639632,2.497366775329,1.33243694265115,-6.78396378716369,-15.4153849212396,0.465511605096266,-0.39438126178315,1.05410721205494,0.974058515963307,-1.45366801871907,-1.42561990549746,0.577661575273881,0.836807763068655,2.84494961758243,1.61350955823594,2.54831265500006,-0.475126442823018,-6.38913186553574,2.24996439320029,1.67050826686181,0.140450002467555,0.162147414308657,1.20773090940574,1.26895846837763,0.097538236000963,12.31)

# input_data as numpy array
input_data_as_numpy = np.asarray(input_data)

# reshape the nupy array as we are predicting 
input_data_reshaped = input_data_as_numpy.reshape(1, -1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if prediction[0]==0:
  print("This is not fraudulent Transaction")
else:
  print("This is fraudulent Transaction")
# Out:
# [1]
# This is fraudulent Transaction
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
